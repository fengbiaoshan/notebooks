# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'as', 'term', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.675835
# Nearest to this: williamsburg, corinthians, stead, burgh, utmost, unvoiced, bayonet, orchestras,
# Nearest to five: nanosystems, eth, esa, tutorial, honeycomb, ignatius, amerindians, koans,
# Nearest to seven: bnetd, xena, away, wyndham, lyme, appealing, marais, coax,
# Nearest to in: mitzvah, ironclad, radiometric, credence, consoles, banister, doraemon, maghrib,
# Nearest to had: umpire, abruzzo, suggestibility, html, crypto, pinky, gernika, strelitz,
# Nearest to as: storytelling, suffer, praia, kpa, mourn, vibration, complied, thorough,
# Nearest to their: druid, harassment, leviathan, emphatic, ubiquity, zambezi, kala, tombalbaye,
# Nearest to no: shea, hyksos, lumen, pang, dickinson, kinsey, sought, teen,
# Nearest to to: exhortations, kilkenny, infidelity, eidyn, debunked, vis, lifeson, blinded,
# Nearest to four: crushed, reyes, categorical, steam, londinium, emil, gasp, epistemology,
# Nearest to is: kinase, spinster, cpm, tanaka, jurists, airfield, recipes, alphabet,
# Nearest to his: foonly, sprache, cheerleading, detection, mitzvot, mitochondria, sarai, yoga,
# Nearest to these: rb, renderer, multinational, darboux, microevolution, chocolates, devanagari, polyn,
# Nearest to and: vectorborne, thrush, promulgate, spec, jdf, nellie, midwest, microstates,
# Nearest to new: freddy, ahmad, coy, boneyard, tramways, bestselling, cpm, pennies,
# Nearest to up: labour, unjustified, chopin, pitted, statuette, pathway, procedural, bellum,
# Average loss at step 2000: 4.361987
# Average loss at step 4000: 3.873280
# Average loss at step 6000: 3.787524
# Average loss at step 8000: 3.684624
# Average loss at step 10000: 3.614304
# Nearest to this: it, the, which, csu, his, a, shenzhen, reel,
# Nearest to five: six, four, eight, nine, seven, three, zero, two,
# Nearest to seven: eight, six, nine, three, five, four, zero, two,
# Nearest to in: of, on, at, from, for, since, weu, by,
# Nearest to had: has, have, was, could, were, bullying, credits, cyanides,
# Nearest to as: vengeance, lamp, deafness, menstruation, utter, bag, spinoffs, yeho,
# Nearest to their: its, his, the, leviathan, foo, disrupting, cells, oscillation,
# Nearest to no: disasters, adar, gamble, came, additive, kinsey, shea, orloff,
# Nearest to to: eidyn, would, tomcat, hooper, alyattes, api, entities, can,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to is: was, are, has, been, archaeologists, although, conferencing, though,
# Nearest to his: their, her, the, s, its, this, suez, incapacity,
# Nearest to these: mighty, beaufort, conceives, expressionism, desai, kidnap, buren, sudetenland,
# Nearest to and: or, who, s, of, regarding, equiv, but, hitachi,
# Nearest to new: jaeger, requires, freddy, teresa, denny, tetra, laird, rene,
# Nearest to up: labour, pathway, atolls, fencing, chopin, harpo, monet, dinara,
# Average loss at step 12000: 3.606599
# Average loss at step 14000: 3.573362
# Average loss at step 16000: 3.410714
# Average loss at step 18000: 3.458129
# Average loss at step 20000: 3.543187
# Nearest to this: it, which, shell, the, a, he, epics, unannounced,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Nearest to seven: eight, six, nine, five, four, three, zero, two,
# Nearest to in: at, on, from, and, for, with, of, between,
# Nearest to had: has, have, were, was, bullying, could, instability, having,
# Nearest to as: thorough, vengeance, enlarging, deafness, actual, inescapable, imparting, became,
# Nearest to their: its, his, the, these, some, foo, her, reduplication,
# Nearest to no: oriental, lumen, gamble, hanseatic, a, disasters, habilitation, reprinted,
# Nearest to to: kilkenny, will, would, not, eidyn, must, can, blinded,
# Nearest to four: six, three, five, seven, eight, two, nine, zero,
# Nearest to is: was, are, has, be, were, clinically, pyramidal, gylfaginning,
# Nearest to his: their, her, its, some, incapacity, antibody, dissension, detection,
# Nearest to these: many, some, their, several, other, which, all, buren,
# Nearest to and: or, in, for, but, regarding, symmetries, teenage, amnesia,
# Nearest to new: requires, jaeger, denny, tetra, single, suit, polygon, penguin,
# Nearest to up: labour, pathway, atolls, fencing, drifted, monet, widgets, xxiii,
# Average loss at step 22000: 3.498976
# Average loss at step 24000: 3.490989
# Average loss at step 26000: 3.482764
# Average loss at step 28000: 3.480224
# Average loss at step 30000: 3.503523
# Nearest to this: which, it, that, any, some, rubidium, what, he,
# Nearest to five: four, three, eight, seven, six, nine, zero, two,
# Nearest to seven: eight, nine, six, four, five, three, two, one,
# Nearest to in: at, during, on, since, of, from, and, with,
# Nearest to had: has, have, was, were, bullying, is, when, could,
# Nearest to as: vengeance, under, remediation, industries, became, dec, unlawful, when,
# Nearest to their: its, his, the, these, her, some, disrupting, many,
# Nearest to no: hanseatic, oriental, zeit, gamble, habilitation, disasters, hut, a,
# Nearest to to: can, will, kilkenny, not, would, eidyn, for, must,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to is: was, has, are, nay, had, became, although, be,
# Nearest to his: her, their, its, the, s, my, incapacity, nazism,
# Nearest to these: some, many, several, their, they, such, other, which,
# Nearest to and: or, but, in, wayward, accountant, amnesia, alex, jvm,
# Nearest to new: requires, jaeger, denny, single, tetra, sequencers, melisende, html,
# Nearest to up: labour, pathway, atolls, fencing, off, drifted, monet, widgets,
# Average loss at step 32000: 3.499342
# Average loss at step 34000: 3.495258
# Average loss at step 36000: 3.452355
# Average loss at step 38000: 3.302633
# Average loss at step 40000: 3.426227
# Nearest to this: which, it, any, some, the, that, another, rubidium,
# Nearest to five: seven, six, three, four, eight, nine, zero, two,
# Nearest to seven: five, six, eight, nine, three, four, two, one,
# Nearest to in: of, during, for, from, on, and, ethiopians, at,
# Nearest to had: has, have, was, were, bullying, successfully, began, jg,
# Nearest to as: by, favoring, dialogue, possesses, giuliano, when, pcb, escu,
# Nearest to their: its, his, her, the, these, some, any, reduplication,
# Nearest to no: any, gamble, disasters, hut, hanseatic, oriental, extolling, only,
# Nearest to to: will, can, may, kilkenny, must, alyattes, bladed, could,
# Nearest to four: three, six, five, seven, two, eight, nine, one,
# Nearest to is: was, are, has, trypomastigotes, be, became, albicans, trinitarian,
# Nearest to his: their, her, its, s, my, the, your, nazism,
# Nearest to these: many, some, several, both, they, such, which, their,
# Nearest to and: or, but, in, geer, while, like, secularization, dominican,
# Nearest to new: jaeger, tetra, requires, penguin, denny, sequencers, single, episcopal,
# Nearest to up: off, out, atolls, labour, them, pathway, drifted, fencing,
# Average loss at step 42000: 3.436631
# Average loss at step 44000: 3.454934
# Average loss at step 46000: 3.449504
# Average loss at step 48000: 3.352621
# Average loss at step 50000: 3.383704
# Nearest to this: which, it, the, shenzhen, some, rubidium, radiotherapy, he,
# Nearest to five: four, six, eight, seven, three, zero, nine, two,
# Nearest to seven: six, eight, nine, three, five, four, two, zero,
# Nearest to in: during, since, on, from, within, at, aki, between,
# Nearest to had: has, have, was, having, were, motors, successfully, could,
# Nearest to as: possesses, oracular, patriarchate, favoring, bauhaus, enlarging, guzman, dialogue,
# Nearest to their: its, his, the, her, these, whose, some, your,
# Nearest to no: any, hut, hypercard, hanseatic, oriental, fictionalized, a, extolling,
# Nearest to to: eidyn, alyattes, would, could, can, must, kilkenny, may,
# Nearest to four: three, six, five, eight, seven, two, nine, zero,
# Nearest to is: was, are, has, although, does, elaine, be, utf,
# Nearest to his: their, her, its, my, the, whose, your, him,
# Nearest to these: some, several, many, both, such, their, those, they,
# Nearest to and: or, but, while, including, who, wojciech, amnesia, like,
# Nearest to new: jaeger, sequencers, tetra, episcopal, requires, sennett, ergaster, single,
# Nearest to up: off, out, them, atolls, him, back, pathway, lechuck,
# Average loss at step 52000: 3.437861
# Average loss at step 54000: 3.428435
# Average loss at step 56000: 3.441160
# Average loss at step 58000: 3.400046
# Average loss at step 60000: 3.393906
# Nearest to this: it, which, that, there, some, what, the, shenzhen,
# Nearest to five: four, six, three, seven, eight, nine, zero, two,
# Nearest to seven: eight, four, nine, five, six, three, zero, one,
# Nearest to in: during, within, since, of, on, at, aki, including,
# Nearest to had: has, have, was, were, makes, having, saw, hallucination,
# Nearest to as: when, thorough, cohesive, guzman, vengeance, enlarging, became, shelby,
# Nearest to their: its, his, her, the, your, whose, our, several,
# Nearest to no: any, hypercard, hut, hanseatic, only, extolling, newborns, little,
# Nearest to to: eidyn, would, kilkenny, api, must, may, will, alyattes,
# Nearest to four: five, three, six, seven, eight, nine, two, zero,
# Nearest to is: was, are, has, although, does, templar, be, if,
# Nearest to his: her, their, its, my, the, whose, your, gpc,
# Nearest to these: many, some, several, both, such, those, which, all,
# Nearest to and: or, but, although, regarding, while, irl, than, logudorese,
# Nearest to new: sequencers, jaeger, ergaster, episcopal, rene, tetra, hr, single,
# Nearest to up: out, off, them, him, back, atolls, pathway, down,
# Average loss at step 62000: 3.241311
# Average loss at step 64000: 3.252945
# Average loss at step 66000: 3.404069
# Average loss at step 68000: 3.399834
# Average loss at step 70000: 3.363443
# Nearest to this: which, it, the, that, there, some, what, a,
# Nearest to five: four, six, eight, seven, three, nine, zero, two,
# Nearest to seven: six, eight, nine, four, five, three, one, two,
# Nearest to in: during, within, on, for, at, of, including, into,
# Nearest to had: have, has, was, were, successfully, been, having, makes,
# Nearest to as: enlarging, when, jokingly, before, thorough, remediation, cara, is,
# Nearest to their: its, his, her, the, your, these, whose, some,
# Nearest to no: any, little, hut, gamble, lumen, newborns, extolling, hypercard,
# Nearest to to: would, must, can, will, eidyn, kilkenny, could, may,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to is: was, has, although, are, be, seems, becomes, became,
# Nearest to his: her, their, its, my, whose, the, marysville, abdul,
# Nearest to these: many, some, such, several, those, various, all, their,
# Nearest to and: or, while, but, like, sulfates, include, including, which,
# Nearest to new: sequencers, ergaster, jaeger, hr, quays, episcopal, lasting, tetra,
# Nearest to up: off, out, them, back, him, atolls, pathway, down,
# Average loss at step 72000: 3.377192
# Average loss at step 74000: 3.350134
# Average loss at step 76000: 3.317019
# Average loss at step 78000: 3.356340
# Average loss at step 80000: 3.377954
# Nearest to this: which, it, the, rubidium, adversus, what, itself, he,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to seven: six, five, eight, four, nine, three, two, zero,
# Nearest to in: during, on, until, at, within, since, through, with,
# Nearest to had: have, has, were, was, began, having, became, attempted,
# Nearest to as: unlawful, when, before, assistive, favoring, yeho, became, after,
# Nearest to their: its, his, her, your, whose, our, these, the,
# Nearest to no: little, any, hanseatic, fictionalized, gamble, hut, habilitation, disasters,
# Nearest to to: eidyn, kilkenny, would, ppc, alyattes, into, must, garuda,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to is: was, has, are, although, nay, mortimer, does, be,
# Nearest to his: her, their, my, its, your, our, the, whose,
# Nearest to these: several, those, many, both, some, various, such, they,
# Nearest to and: or, while, but, julien, than, tarski, including, waldheim,
# Nearest to new: rene, jaeger, sequencers, ergaster, hr, tetra, episcopal, single,
# Nearest to up: off, out, them, him, back, down, atolls, pathway,
# Average loss at step 82000: 3.404161
# Average loss at step 84000: 3.407627
# Average loss at step 86000: 3.392462
# Average loss at step 88000: 3.348562
# Average loss at step 90000: 3.367110
# Nearest to this: which, it, some, another, the, shenzhen, rubidium, any,
# Nearest to five: seven, eight, four, three, six, nine, two, zero,
# Nearest to seven: eight, four, six, five, nine, three, one, two,
# Nearest to in: during, within, under, near, with, of, ethiopians, among,
# Nearest to had: has, have, was, were, having, attempted, began, been,
# Nearest to as: strident, favoring, filmmaker, rojcewicz, unlawful, cara, muhammed, bauhaus,
# Nearest to their: its, his, her, your, our, whose, the, reduplication,
# Nearest to no: any, little, fictionalized, only, than, detached, hanseatic, habilitation,
# Nearest to to: eidyn, debunked, kilkenny, towards, guildhall, would, must, doric,
# Nearest to four: seven, five, six, eight, three, two, nine, one,
# Nearest to is: was, has, are, although, makes, does, becomes, be,
# Nearest to his: her, their, its, your, my, our, whose, the,
# Nearest to these: many, some, several, those, are, various, such, all,
# Nearest to and: or, but, including, logudorese, while, regarding, irl, in,
# Nearest to new: enix, hr, jaeger, rene, quays, different, tetra, ergaster,
# Nearest to up: out, off, them, back, him, down, atolls, pathway,
# Average loss at step 92000: 3.400034
# Average loss at step 94000: 3.250478
# Average loss at step 96000: 3.358076
# Average loss at step 98000: 3.247286
# Average loss at step 100000: 3.360022
# Nearest to this: it, which, itself, another, the, he, what, some,
# Nearest to five: six, seven, four, eight, three, zero, nine, two,
# Nearest to seven: eight, six, four, five, nine, three, two, zero,
# Nearest to in: during, within, on, until, throughout, among, tegucigalpa, at,
# Nearest to had: has, have, was, were, attempted, having, would, began,
# Nearest to as: enlarging, coordinators, underwater, concisely, mabuse, throughout, rojcewicz, assistive,
# Nearest to their: its, his, her, your, whose, the, our, reduplication,
# Nearest to no: any, little, hut, understandable, disasters, only, fictionalized, plausible,
# Nearest to to: eidyn, will, kilkenny, could, must, would, can, towards,
# Nearest to four: seven, six, five, eight, three, two, nine, zero,
# Nearest to is: was, has, are, remains, became, seems, be, becomes,
# Nearest to his: her, their, your, my, its, our, whose, the,
# Nearest to these: many, several, some, those, various, all, such, multiple,
# Nearest to and: or, but, like, including, while, regarding, when, although,
# Nearest to new: different, jaeger, quays, single, tak, marriageable, hr, ergaster,
# Nearest to up: off, out, back, them, him, down, together, atolls,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, num_context):
  global data_index
  batch_size = batch_size*num_context   #len(batch) is num_context*len(labels)     context(x) -> x
  assert batch_size % num_context == 0
  context_batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size//num_context, 1), dtype=np.int32)
  span = num_context + 1 #contextleft + target + contextright
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_context):
    target = num_context//2  # target label at the center of the buffer
    targets_to_avoid = [ target ]
    labels[i, 0] = buffer[target]
    for j in range(num_context):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      context_batch[i * num_context + j] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return context_batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

data_index = 0
batch, labels = generate_batch(batch_size=8, num_context=2)
print('\nwith num_context = 2:')
print('    batch:', [reverse_dictionary[bi] for bi in batch])
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_context = 2:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'abuse', 'term', 'of', 'first', 'used', 'abuse', 'first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']

# %%
batch_size = 64
embedding_size = 128 # Dimension of the embedding vector.
num_context = 2
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 32 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size*num_context])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  for i in range(batch_size):
    sum_context = tf.Variable(tf.zeros([1,embedding_size]))
    for j in range(num_context):
        sum_context = tf.add(sum_context, embed[i*num_context+j,:])
    if i != 0:
        input_data = tf.concat([input_data, sum_context], 0)
    else:
        input_data = sum_context
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=input_data,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_context)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.534913
# Nearest to more: journalist, cheap, allowed, bletchley, wolf, bitumen, disassembly, punishable,
# Nearest to with: jordi, practice, doth, materials, orthogonality, bundesl, dusseldorf, grouse,
# Nearest to nine: copps, defector, talal, lite, magnesians, badges, planners, fidelity,
# Nearest to called: ach, objectivist, thermochemistry, blood, arrives, turnaround, narration, blinding,
# Nearest to system: rda, peng, spaceship, wrought, dissolve, elke, gran, uprisings,
# Nearest to such: ley, engenders, genome, loti, tit, mercator, haq, imitations,
# Nearest to s: refreshing, epa, normally, nou, degenerative, integrins, exarchate, fei,
# Nearest to the: criswell, replicator, nuns, reproducing, postulating, parasites, risk, lothar,
# Nearest to while: lynyrd, noir, settler, maris, rumelia, storehouse, ordeal, krugerrand,
# Nearest to a: ici, answerable, encoding, ribera, louth, alchemy, mental, langue,
# Nearest to was: bahadur, volker, icosahedron, mendes, kyiv, charley, tap, tb,
# Nearest to used: cruz, oder, pelagic, loophole, dbu, psychological, katanga, carmack,
# Nearest to two: loaded, aquariums, cfp, backstage, serve, pepe, collectivization, celebrations,
# Nearest to united: russcol, mf, hostility, fee, statutory, disdained, electron, beings,
# Nearest to been: basements, heft, france, issa, ito, vienna, factional, vice,
# Nearest to most: wormholes, oligopoly, bond, bertram, worthy, gholas, alien, decorum,
# Average loss at step 2000: 3.680146
# Average loss at step 4000: 3.146961
# Average loss at step 6000: 3.047992
# Average loss at step 8000: 2.990135
# Average loss at step 10000: 2.796470
# Nearest to more: most, less, very, greater, rather, nieve, pathology, thirties,
# Nearest to with: between, in, and, through, into, by, on, after,
# Nearest to nine: eight, seven, six, zero, five, four, three, two,
# Nearest to called: trek, objectivist, layering, ach, generous, sovereigns, statistician, given,
# Nearest to system: emilia, reuel, lark, kar, spaceship, dentistry, jr, lucasarts,
# Nearest to such: well, known, engenders, these, acts, backspace, just, crime,
# Nearest to s: isbn, american, befall, news, drivers, gilded, famed, irradiated,
# Nearest to the: this, its, their, each, a, anzus, his, spike,
# Nearest to while: although, geisel, are, until, mikoto, from, lynyrd, storehouse,
# Nearest to a: the, each, struggle, no, trumps, any, balder, relapse,
# Nearest to was: is, has, were, had, are, but, finnic, stayed,
# Nearest to used: sardonic, known, isostatic, affreightment, defined, pumpkin, ltspkr, carpets,
# Nearest to two: one, seven, six, five, three, zero, four, nine,
# Nearest to united: disdained, calorimetry, hostility, russcol, archery, microbial, undoubtedly, landlord,
# Nearest to been: provisional, be, supplying, exporters, fischer, lineup, someday, prosper,
# Nearest to most: more, anemometer, worthy, romanis, forrestal, andalusian, oligopoly, healed,
# Average loss at step 12000: 2.761584
# Average loss at step 14000: 2.803686
# Average loss at step 16000: 2.748904
# Average loss at step 18000: 2.719632
# Average loss at step 20000: 2.686472
# Nearest to more: less, most, very, higher, rather, greater, kiwifruit, longer,
# Nearest to with: between, or, through, against, from, in, by, of,
# Nearest to nine: eight, seven, five, six, four, zero, three, two,
# Nearest to called: considered, referred, see, given, listed, performed, fk, globe,
# Nearest to system: systems, walton, hilda, permanence, method, dentistry, complains, fifths,
# Nearest to such: well, known, these, many, backspace, rieure, regarded, engenders,
# Nearest to s: his, of, isbn, and, although, brigid, dignified, prefectures,
# Nearest to the: their, his, its, a, any, her, this, all,
# Nearest to while: although, but, though, as, are, were, and, until,
# Nearest to a: the, any, no, another, yards, kissed, trumps, liguria,
# Nearest to was: is, had, has, became, were, does, through, did,
# Nearest to used: seen, known, located, isostatic, defined, considered, injurious, elected,
# Nearest to two: three, four, eight, seven, five, one, six, nine,
# Nearest to united: disdained, lowlands, archery, landlord, metallic, borgia, oceans, hostility,
# Nearest to been: become, be, were, hers, fischer, palacio, never, kattegat,
# Nearest to most: more, worthy, many, variance, ainsworth, kurgan, forrestal, talleyrand,
# Average loss at step 22000: 2.661802
# Average loss at step 24000: 2.561522
# Average loss at step 26000: 2.488678
# Average loss at step 28000: 2.565824
# Average loss at step 30000: 2.475247
# Nearest to more: less, greater, rather, higher, most, very, longer, kiwifruit,
# Nearest to with: between, and, in, through, among, into, including, against,
# Nearest to nine: eight, seven, six, five, zero, four, three, two,
# Nearest to called: considered, referred, named, bengal, performed, listed, bodleian, com,
# Nearest to system: systems, reuel, dentistry, method, community, effecting, wiltshire, crosstown,
# Nearest to such: known, well, these, distinct, acts, unbalanced, rieure, regarded,
# Nearest to s: isbn, whose, and, his, judy, bol, persson, bag,
# Nearest to the: their, his, its, this, any, a, our, another,
# Nearest to while: although, until, though, before, and, including, spamalot, are,
# Nearest to a: the, another, any, his, every, no, disagreeable, dentistry,
# Nearest to was: is, had, became, were, has, been, be, does,
# Nearest to used: known, considered, seen, found, able, located, referred, defined,
# Nearest to two: three, four, six, five, seven, eight, nine, zero,
# Nearest to united: disdained, landlord, undoubtedly, russcol, lowlands, past, archery, oyly,
# Nearest to been: become, be, was, always, were, rale, remained, oldfield,
# Nearest to most: more, some, ainsworth, among, forrestal, bucks, spectrum, less,
# Average loss at step 32000: 2.500932
# Average loss at step 34000: 2.519749
# Average loss at step 36000: 2.506645
# Average loss at step 38000: 2.557581
# Average loss at step 40000: 2.517008
# Nearest to more: less, very, most, greater, rather, higher, kiwifruit, quite,
# Nearest to with: between, including, among, in, by, into, during, through,
# Nearest to nine: eight, seven, six, five, zero, two, four, three,
# Nearest to called: considered, referred, resumption, classics, used, named, listed, boasted,
# Nearest to system: systems, community, discouraging, manufacturing, offside, xinjiang, habitual, network,
# Nearest to such: known, well, these, regarded, rieure, early, hom, many,
# Nearest to s: isbn, whose, his, although, was, gell, and, befall,
# Nearest to the: their, its, this, his, a, any, our, each,
# Nearest to while: although, when, before, but, during, and, however, until,
# Nearest to a: another, the, any, no, libert, preoccupied, this, every,
# Nearest to was: is, were, had, has, became, does, s, are,
# Nearest to used: published, found, known, able, seen, referred, released, operate,
# Nearest to two: three, six, five, eight, zero, four, nine, one,
# Nearest to united: western, disdained, lowlands, landlord, undoubtedly, braille, oceans, archery,
# Nearest to been: become, be, was, never, spree, remained, rale, inaccuracies,
# Nearest to most: more, worthy, less, leyden, suspicious, dreamer, leakey, several,
# Average loss at step 42000: 2.471182
# Average loss at step 44000: 2.300818
# Average loss at step 46000: 2.446917
# Average loss at step 48000: 2.488101
# Average loss at step 50000: 2.481790
# Nearest to more: less, most, very, rather, greater, smaller, better, higher,
# Nearest to with: between, in, by, among, against, during, of, under,
# Nearest to nine: eight, seven, six, four, zero, five, three, two,
# Nearest to called: considered, named, referred, classics, offered, designed, thunderbirds, said,
# Nearest to system: systems, community, reprogramming, tube, alcs, network, complains, discouraging,
# Nearest to such: well, known, follows, these, regarded, rieure, few, blanche,
# Nearest to s: whose, isbn, his, and, although, honeybee, prefectures, references,
# Nearest to the: their, his, its, a, this, some, hunnish, another,
# Nearest to while: although, though, however, including, despite, until, for, during,
# Nearest to a: the, another, no, any, this, disagreeable, calais, very,
# Nearest to was: is, had, has, became, were, britons, subsequently, does,
# Nearest to used: known, required, described, seen, published, found, elected, written,
# Nearest to two: three, four, five, seven, one, six, eight, nine,
# Nearest to united: uk, lowlands, disdained, lombards, oceans, following, braille, western,
# Nearest to been: become, be, recently, ever, was, never, spenser, were,
# Nearest to most: more, bucks, many, less, ainsworth, some, neighbourhoods, leyden,
# Average loss at step 52000: 2.500300
# Average loss at step 54000: 2.466062
# Average loss at step 56000: 2.425936
# Average loss at step 58000: 2.275102
# Average loss at step 60000: 2.368994
# Nearest to more: less, most, very, greater, rather, highly, smaller, quite,
# Nearest to with: between, within, among, in, yusef, before, from, behind,
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to called: named, referred, considered, designed, shamanistic, used, see, classics,
# Nearest to system: systems, network, reform, community, reprogramming, einsteinium, lintel, service,
# Nearest to such: well, known, these, rieure, many, regarded, follows, cited,
# Nearest to s: isbn, whose, his, although, brigid, of, and, ceos,
# Nearest to the: their, a, its, his, this, any, another, each,
# Nearest to while: though, although, but, when, however, until, and, where,
# Nearest to a: the, another, any, no, lignite, calais, suffragist, this,
# Nearest to was: is, were, had, became, has, becomes, been, then,
# Nearest to used: known, described, seen, published, referred, required, expressed, defined,
# Nearest to two: three, four, five, seven, eight, six, one, nine,
# Nearest to united: lowlands, borgia, following, lombards, vidkun, undoubtedly, western, kiki,
# Nearest to been: become, be, were, was, never, forbes, remained, recently,
# Nearest to most: more, less, many, among, ainsworth, cleansed, all, dollfuss,
# Average loss at step 62000: 2.464393
# Average loss at step 64000: 2.358923
# Average loss at step 66000: 2.346249
# Average loss at step 68000: 2.379865
# Average loss at step 70000: 2.361184
# Nearest to more: less, higher, larger, greater, very, most, rather, smaller,
# Nearest to with: between, while, for, by, among, after, in, within,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to called: named, referred, considered, designed, servo, said, known, used,
# Nearest to system: systems, network, technology, model, process, lintel, mikvah, belew,
# Nearest to such: well, known, these, many, possible, important, mentality, early,
# Nearest to s: isbn, whose, his, my, harley, her, est, your,
# Nearest to the: his, its, their, a, whose, this, any, our,
# Nearest to while: although, though, and, after, however, but, despite, with,
# Nearest to a: another, the, any, every, no, lignite, sais, disagreeable,
# Nearest to was: is, had, has, became, were, does, are, becomes,
# Nearest to used: known, described, available, applied, defined, responsible, mentioned, required,
# Nearest to two: three, seven, six, four, eight, five, one, nine,
# Nearest to united: lowlands, sovereign, borgia, landlord, invictus, vidkun, dmc, diatoms,
# Nearest to been: become, be, was, remained, since, were, traditionally, zines,
# Nearest to most: more, less, especially, some, suspicious, among, highly, because,
# Average loss at step 72000: 2.407034
# Average loss at step 74000: 2.385670
# Average loss at step 76000: 2.320002
# Average loss at step 78000: 2.215764
# Average loss at step 80000: 2.371098
# Nearest to more: less, greater, larger, most, very, faster, higher, smaller,
# Nearest to with: between, among, by, and, without, or, of, in,
# Nearest to nine: eight, seven, six, five, four, zero, two, three,
# Nearest to called: named, used, referred, designed, known, bathing, offered, sardonic,
# Nearest to system: systems, network, model, lintel, hd, hilda, structure, chiuchow,
# Nearest to such: well, these, having, follows, known, possible, emerged, much,
# Nearest to s: whose, isbn, and, his, your, ceos, hayes, my,
# Nearest to the: a, their, this, his, our, any, your, its,
# Nearest to while: although, but, and, despite, though, however, including, when,
# Nearest to a: the, another, any, every, this, no, alam, lignite,
# Nearest to was: is, were, had, has, became, been, after, becomes,
# Nearest to used: described, called, introduced, designed, defined, applied, known, responsible,
# Nearest to two: four, five, seven, one, three, six, eight, nine,
# Nearest to united: sovereign, borgia, landlord, lowlands, uk, caribbean, vance, dmc,
# Nearest to been: become, was, remained, already, previously, be, were, recently,
# Nearest to most: more, less, many, some, because, especially, heathers, worthy,
# Average loss at step 82000: 2.312279
# Average loss at step 84000: 2.322936
# Average loss at step 86000: 2.330311
# Average loss at step 88000: 2.273261
# Average loss at step 90000: 2.181725
# Nearest to more: less, very, larger, greater, smaller, faster, highly, longer,
# Nearest to with: between, in, by, during, within, and, among, through,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to called: named, used, sardonic, designed, bathing, referred, see, based,
# Nearest to system: systems, network, redgrave, dashing, community, structure, architecture, method,
# Nearest to such: well, known, these, many, seen, certain, notable, mentality,
# Nearest to s: whose, isbn, his, and, although, of, becomes, your,
# Nearest to the: a, its, his, their, this, your, our, her,
# Nearest to while: although, however, before, when, after, were, whereas, though,
# Nearest to a: the, another, this, any, libert, disraeli, every, or,
# Nearest to was: is, were, became, had, has, does, being, been,
# Nearest to used: described, known, required, available, referred, defined, applied, found,
# Nearest to two: three, four, six, five, seven, eight, zero, nine,
# Nearest to united: sovereign, caribbean, landlord, borgia, oceans, uk, dissuade, kiki,
# Nearest to been: become, remained, was, were, already, be, traditionally, zines,
# Nearest to most: less, more, many, some, especially, worthy, aloof, all,
# Average loss at step 92000: 1.663669
# Average loss at step 94000: 2.049953
# Average loss at step 96000: 2.004267
# Average loss at step 98000: 2.168833
# Average loss at step 100000: 2.227580
# Nearest to more: less, most, greater, rather, larger, highly, very, faster,
# Nearest to with: between, by, in, through, and, within, takes, using,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to called: named, used, referred, designed, bathing, see, proposed, per,
# Nearest to system: systems, network, structure, districts, revenue, branch, blige, redgrave,
# Nearest to such: well, many, known, these, certain, regarded, including, mentality,
# Nearest to s: whose, isbn, vs, our, his, references, although, and,
# Nearest to the: a, their, any, this, his, its, her, our,
# Nearest to while: although, when, though, before, and, however, were, until,
# Nearest to a: the, another, this, any, or, no, disagreeable, lignite,
# Nearest to was: is, had, has, became, were, seems, does, would,
# Nearest to used: introduced, applied, needed, required, designed, described, known, referred,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to united: sovereign, caribbean, arab, uk, oceans, landlord, kiki, roman,
# Nearest to been: become, traditionally, already, be, remained, were, was, recently,
# Nearest to most: more, some, less, many, worthy, greatest, especially, suspicious,

# %% [markdown]
# ### plot embed vector

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_dim_vector = tsne.fit_transform(final_embeddings[1:50])
plot_labels = [reverse_dictionary[i] for i in range(1, 50)]
pylab.figure(figsize=(15,15))  # in inches
for i, label in enumerate(plot_labels):
    x, y = two_dim_vector[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
pylab.show()
